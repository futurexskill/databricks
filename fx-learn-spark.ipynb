# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6736733238690623#setting/sparkui/0129-133022-lenuefn8/driver-8743095342677256397">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.createDataFrame([{"Google": "Colab","Spark": "Scala"} ,{"Google": "Dataproc","Spark":"Python"}]).show()
# Out:
# +--------+------+
# |  Google| Spark|
# +--------+------+
# |   Colab| Scala|
# |Dataproc|Python|
# +--------+------+

# %%
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
# ...

# %%
dbutils.fs.ls("dbfs:/")
# Out:
# Out[8]: [FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0)]

# %%
dbutils.fs.ls("dbfs:/databricks-datasets")
# Out:
# Out[9]: [FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1532468253000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1455043490000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=0),
# ...

# %%
dbutils.fs.ls("/databricks-datasets")
# Out:
# Out[10]: [FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1532468253000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1455043490000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=0),
# ...

# %%
dbutils.fs.ls("/databricks-datasets/credit-card-fraud")
# Out:
# Out[11]: [FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/LICENSE', name='LICENSE', size=27, modificationTime=1518065620000),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/data/', name='data/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/dbcl-10.txt', name='dbcl-10.txt', size=2382, modificationTime=1518065620000),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/description.txt', name='description.txt', size=2001, modificationTime=1518065620000),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/odbl-10.txt', name='odbl-10.txt', size=25317, modificationTime=1518065620000)]

# %%
# %fs
ls /databricks-datasets/credit-card-fraud
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
credit_fraud = spark.read.csv("dbfs:/databricks-datasets/credit-card-fraud/odbl-10.txt")

# %%
credit_fraud.show()
# Out:
# +--------------------+
# |                 _c0|
# +--------------------+
# |## ODC Open Datab...|
# |        ### Preamble|
# |The Open Database...|
# |allow users to fr...|
# |maintaining this ...|
# |           copyright|
# |       jurisdictions|
# |     cover databases|
# |the ODbL is also ...|
# |act in certain wa...|
# |Databases can con...|
# |audiovisual material|
# |and so the ODbL o...|
# |contents of the D...|
# |together with ano...|
# |single set of rig...|
# |contents have mul...|
# |describe what rig...|
# |record or in some...|
# |Sometimes the con...|
# +--------------------+
# only showing top 20 rows

# %%
df = spark.createDataFrame([{"Google": "Colab","Spark": "Scala"} ,{"Google": "Dataproc","Spark":"Python"}])

# %%
type(df)
# Out:
# Out[22]: pyspark.sql.dataframe.DataFrame

# %%
customer_df = spark.sql("select * from default.store_customers")

# %%
customer_df.show()
# Out:
# +----------+---+------+------+-------+
# |CustomerID|Age|Salary|Gender|Country|
# +----------+---+------+------+-------+
# |         1| 72| 20000|  Male|Germany|
# |         2| 72| 22000|Female| France|
# |         3| 70| 24000|Female|England|
# |         4| 75|  2600|  Male|England|
# |         5| 33| 50000|  Male| France|
# |         6| 52| 35000|Female|England|
# |         7| 31|  4300|  Male|Germany|
# |         8| 37| 32000|Female| France|
# |         9| 76| 35000|  Male|Germany|
# |        10| 58| 37000|Female| France|
# |        11| 70| 25000|  Male|Germany|
# |        12| 28| 27000|Female| France|
# |        13| 21| 29000|Female|England|
# |        14| 34|  7600|  Male|England|
# |        15| 45| 55000|  Male| France|
# |        16| 32| 40000|Female|England|
# |        17| 62|  9300|  Male|Germany|
# |        18| 54| 37000|Female| France|
# |        19| 33| 40000|  Male|Germany|
# |        20| 46| 42000|Female| France|
# +----------+---+------+------+-------+
# ...

# %%
customer_df.count()
# Out:
# Out[26]: 7000

# %%
display(customer_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
customer_df.write.format('delta').saveAsTable("customer_delta")
