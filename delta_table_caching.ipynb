# %%
# %fs

ls /databricks-datasets/nyctaxi/tripdata/yellow/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %fs

ls /databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-01.csv.gz
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-01.csv.gz</td><td>yellow_tripdata_2009-01.csv.gz</td><td>504262564</td><td>1590475761000</td></tr></tbody></table></div>

# %%
nytaxi_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("codec", "gzip") \
    .load("/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-01.csv.gz")

# %%
nytaxi_df.count()
# Out:
# Out[2]: 14092413

# %%
nytaxi_df.show()
# Out:
# +-----------+--------------------+---------------------+---------------+-------------+----------+---------+---------+-----------------+----------+---------+------------+--------+---------+-------+-------+---------+---------+
# |vendor_name|Trip_Pickup_DateTime|Trip_Dropoff_DateTime|Passenger_Count|Trip_Distance| Start_Lon|Start_Lat|Rate_Code|store_and_forward|   End_Lon|  End_Lat|Payment_Type|Fare_Amt|surcharge|mta_tax|Tip_Amt|Tolls_Amt|Total_Amt|
# +-----------+--------------------+---------------------+---------------+-------------+----------+---------+---------+-----------------+----------+---------+------------+--------+---------+-------+-------+---------+---------+
# |        VTS| 2009-01-04 02:52:00|  2009-01-04 03:02:00|              1|         2.63|-73.991957|40.721567|     null|             null|-73.993803|40.695922|        CASH|     8.9|      0.5|   null|    0.0|      0.0|      9.4|
# ...

# %%
nytaxi_df.write.format("delta").mode("append").saveAsTable("nytaxi_yellow_trips")

# %%
spark.conf.get("spark.databricks.io.cache.enabled")
# Out:
# Out[5]: 'true'

# %%
spark.conf.set("spark.databricks.io.cache.enabled","false")

# %%
spark.conf.get("spark.databricks.io.cache.enabled")
# Out:
# Out[7]: 'false'

# %%
# %sql

WITH vendors AS (
  SELECT DISTINCT vendor_name
  FROM nytaxi_yellow_trips
)
SELECT COUNT(*) AS distinct_vendor_count
FROM vendors
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distinct_vendor_count</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %%
# %sql

WITH vendors AS (
  SELECT DISTINCT vendor_name
  FROM nytaxi_yellow_trips
)
SELECT COUNT(*) AS distinct_vendor_count
FROM vendors
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distinct_vendor_count</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %%
spark.conf.set("spark.databricks.io.cache.enabled","true")

# %%
# %sql

WITH vendors AS (
  SELECT DISTINCT vendor_name
  FROM nytaxi_yellow_trips
)
SELECT COUNT(*) AS distinct_vendor_count
FROM vendors
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distinct_vendor_count</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %%
# %sql

WITH vendors AS (
  SELECT DISTINCT vendor_name
  FROM nytaxi_yellow_trips
)
SELECT COUNT(*) AS distinct_vendor_count
FROM vendors
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distinct_vendor_count</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %%
# %sql

WITH vendors AS (
  SELECT DISTINCT vendor_name
  FROM nytaxi_yellow_trips
)
SELECT COUNT(*) AS distinct_vendor_count
FROM vendors
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>distinct_vendor_count</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %%
distinct_vendor_count = nytaxi_df.select("vendor_name").distinct().count()

# %%
distinct_vendor_count
# Out:
# Out[16]: 3

# %%
distinct_vendor_count = nytaxi_df.select("vendor_name").distinct().count()

# %%
# %sql

SELECT vendor_name, count(*) as count
FROM nytaxi_yellow_trips
WHERE Payment_Type = "Credit" AND Fare_Amt > 10
GROUP BY vendor_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_name</th><th>count</th></tr></thead><tbody><tr><td>CMT</td><td>554367</td></tr><tr><td>VTS</td><td>611812</td></tr></tbody></table></div>

# %%
# %sql

SELECT vendor_name, count(*) as count
FROM nytaxi_yellow_trips
WHERE Payment_Type = "Credit" AND Fare_Amt > 10
GROUP BY vendor_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_name</th><th>count</th></tr></thead><tbody><tr><td>CMT</td><td>554367</td></tr><tr><td>VTS</td><td>611812</td></tr></tbody></table></div>

# %%
# %sql

SELECT vendor_name, count(*) as count
FROM nytaxi_yellow_trips
WHERE Payment_Type = "Credit" AND Fare_Amt > 10
GROUP BY vendor_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_name</th><th>count</th></tr></thead><tbody><tr><td>CMT</td><td>554367</td></tr><tr><td>VTS</td><td>611812</td></tr></tbody></table></div>

# %%
spark.conf.set("spark.databricks.io.cache.enabled","false")

# %%
# %sql

SELECT vendor_name, count(*) as count
FROM nytaxi_yellow_trips
WHERE Payment_Type = "Credit" AND Fare_Amt > 10
GROUP BY vendor_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_name</th><th>count</th></tr></thead><tbody><tr><td>CMT</td><td>554367</td></tr><tr><td>VTS</td><td>611812</td></tr></tbody></table></div>

# %%
# %sql

SELECT vendor_name, count(*) as count
FROM nytaxi_yellow_trips
WHERE Payment_Type = "Credit" AND Fare_Amt > 10
GROUP BY vendor_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_name</th><th>count</th></tr></thead><tbody><tr><td>CMT</td><td>554367</td></tr><tr><td>VTS</td><td>611812</td></tr></tbody></table></div>
